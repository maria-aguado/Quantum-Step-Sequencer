# %%
import qiskit as qk #quantum computing library
from qiskit.quantum_info import Statevector #Statevector is a vector in the 2**n dimensional complex Hilbert space. It has coefficients.
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\dormi\Desktop\cub\circuit.ipynb Cell 1 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dormi/Desktop/cub/circuit.ipynb#W0sZmlsZQ%3D%3D?line=0'>1</a> import qiskit as qk #quantum computing library
#       <a href='vscode-notebook-cell:/c%3A/Users/dormi/Desktop/cub/circuit.ipynb#W0sZmlsZQ%3D%3D?line=1'>2</a> from qiskit.quantum_info import Statevector #Statevector is a vector in the 2**n dimensional complex Hilbert space. It has coefficients.
#       <a href='vscode-notebook-cell:/c%3A/Users/dormi/Desktop/cub/circuit.ipynb#W0sZmlsZQ%3D%3D?line=2'>3</a> import numpy as np
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\__init__.py:67, in <module>
#      64 from qiskit.exceptions import QiskitError, MissingOptionalLibraryError
#      66 # The main qiskit operators
# ---> 67 from qiskit.circuit import ClassicalRegister
#      68 from qiskit.circuit import QuantumRegister
#      69 from qiskit.circuit import AncillaRegister
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\circuit\__init__.py:331, in <module>
#     329 from .quantumcircuitdata import CircuitInstruction
#     330 from .equivalence import EquivalenceLibrary
# --> 331 from . import library
#     332 from .commutation_checker import CommutationChecker
#     334 from .controlflow import (
#     335     ControlFlowOp,
#     336     WhileLoopOp,
#    (...)
#     340     ContinueLoopOp,
#     341 )
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\circuit\library\__init__.py:496, in <module>
#     492 from ..reset import Reset
#     495 from .blueprintcircuit import BlueprintCircuit
# --> 496 from .generalized_gates import (
#     497     Diagonal,
#     498     MCMT,
#     499     MCMTVChain,
#     500     Permutation,
#     501     PermutationGate,
#     502     GMS,
#     503     MSGate,
#     504     GR,
#     505     GRX,
#     506     GRY,
#     507     GRZ,
#     508     RVGate,
#     509     PauliGate,
#     510     LinearFunction,
#     511 )
#     512 from .pauli_evolution import PauliEvolutionGate
#     513 from .boolean_logic import (
#     514     AND,
#     515     OR,
#     516     XOR,
#     517     InnerProduct,
#     518 )
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\circuit\library\generalized_gates\__init__.py:22, in <module>
#      20 from .pauli import PauliGate
#      21 from .rv import RVGate
# ---> 22 from .linear_function import LinearFunction
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\circuit\library\generalized_gates\linear_function.py:19, in <module>
#      17 from qiskit.circuit import QuantumCircuit, Gate
#      18 from qiskit.circuit.exceptions import CircuitError
# ---> 19 from qiskit.synthesis.linear import check_invertible_binary_matrix
#      22 class LinearFunction(Gate):
#      23     r"""A linear reversible circuit on n qubits.
#      24
#      25     Internally, a linear function acting on n qubits is represented
#    (...)
#      61     `Online at umich.edu. <https://web.eecs.umich.edu/~imarkov/pubs/jour/qic08-cnot.pdf>`_
#      62     """
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\synthesis\__init__.py:84, in <module>
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2017, 2020.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 ===========================================
#      15 Circuit Synthesis (:mod:`qiskit.synthesis`)
#    (...)
#      81
#      82 """
# ---> 84 from .evolution import (
#      85     EvolutionSynthesis,
#      86     ProductFormula,
#      87     LieTrotter,
#      88     SuzukiTrotter,
#      89     MatrixExponential,
#      90     QDrift,
#      91 )
#      93 from .permutation import (
#      94     synth_permutation_depth_lnn_kms,
#      95     synth_permutation_basic,
#      96     synth_permutation_acg,
#      97 )
#      98 from .linear import synth_cnot_count_full_pmh, synth_cnot_depth_line_kms
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\synthesis\evolution\__init__.py:17, in <module>
#      15 from .evolution_synthesis import EvolutionSynthesis
#      16 from .matrix_synthesis import MatrixExponential
# ---> 17 from .product_formula import ProductFormula
#      18 from .lie_trotter import LieTrotter
#      19 from .suzuki_trotter import SuzukiTrotter
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\synthesis\evolution\product_formula.py:20, in <module>
#      18 from qiskit.circuit.parameterexpression import ParameterExpression
#      19 from qiskit.circuit.quantumcircuit import QuantumCircuit
# ---> 20 from qiskit.quantum_info import SparsePauliOp, Pauli
#      22 from .evolution_synthesis import EvolutionSynthesis
#      25 class ProductFormula(EvolutionSynthesis):
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\quantum_info\__init__.py:125, in <module>
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2017, 2021.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      12 """
#      13 ================================================
#      14 Quantum Information (:mod:`qiskit.quantum_info`)
#    (...)
#     122    XXDecomposer
#     123 """
# --> 125 from .operators import Operator, ScalarOp, Pauli, Clifford, SparsePauliOp
#     126 from .operators import PauliList, PauliTable, StabilizerTable, pauli_basis
#     127 from .operators.channel import Choi, SuperOp, Kraus, Stinespring, Chi, PTM
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\quantum_info\operators\__init__.py:17, in <module>
#      15 from .channel import PTM, Chi, Choi, Kraus, Stinespring, SuperOp
#      16 from .dihedral import CNOTDihedral
# ---> 17 from .measures import (
#      18     average_gate_fidelity,
#      19     diamond_norm,
#      20     gate_error,
#      21     process_fidelity,
#      22 )
#      23 from .operator import Operator
#      24 from .scalar_op import ScalarOp
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\quantum_info\operators\measures.py:27, in <module>
#      25 from qiskit.quantum_info.operators.channel.quantum_channel import QuantumChannel
#      26 from qiskit.quantum_info.operators.channel import Choi, SuperOp
# ---> 27 from qiskit.quantum_info.states.densitymatrix import DensityMatrix
#      28 from qiskit.quantum_info.states.measures import state_fidelity
#      29 from qiskit.utils import optionals as _optionals
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\quantum_info\states\__init__.py:15, in <module>
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2017, 2019.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """Quantum States."""
# ---> 15 from .statevector import Statevector
#      16 from .stabilizerstate import StabilizerState
#      17 from .densitymatrix import DensityMatrix
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\quantum_info\states\statevector.py:27, in <module>
#      25 from qiskit.circuit.instruction import Instruction
#      26 from qiskit.exceptions import QiskitError
# ---> 27 from qiskit.quantum_info.states.quantum_state import QuantumState
#      28 from qiskit.quantum_info.operators.mixins.tolerances import TolerancesMixin
#      29 from qiskit.quantum_info.operators.operator import Operator
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\quantum_info\states\quantum_state.py:23, in <module>
#      20 import numpy as np
#      22 from qiskit.quantum_info.operators.operator import Operator
# ---> 23 from qiskit.result.counts import Counts
#      26 class QuantumState:
#      27     """Abstract quantum state base class"""
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\result\__init__.py:58, in <module>
#       1 # This code is part of Qiskit.
#       2 #
#       3 # (C) Copyright IBM 2017, 2018.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 =========================================
#      15 Experiment Results (:mod:`qiskit.result`)
#    (...)
#      55
#      56 """
# ---> 58 from .result import Result
#      59 from .exceptions import ResultError
#      60 from .utils import marginal_counts
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\result\result.py:19, in <module>
#      16 import warnings
#      18 from qiskit.circuit.quantumcircuit import QuantumCircuit
# ---> 19 from qiskit.pulse.schedule import Schedule
#      20 from qiskit.exceptions import QiskitError
#      21 from qiskit.quantum_info.states import statevector
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\pulse\__init__.py:61, in <module>
#      13 r"""
#      14 ===========================
#      15 Pulse (:mod:`qiskit.pulse`)
#    (...)
#      57 .. autoclass:: PulseError
#      58 """
#      60 # Builder imports.
# ---> 61 from qiskit.pulse.builder import (
#      62     # Construction methods.
#      63     active_backend,
#      64     active_transpiler_settings,
#      65     active_circuit_scheduler_settings,
#      66     build,
#      67     num_qubits,
#      68     qubit_channels,
#      69     samples_to_seconds,
#      70     seconds_to_samples,
#      71     # Instructions.
#      72     acquire,
#      73     barrier,
#      74     call,
#      75     delay,
#      76     play,
#      77     reference,
#      78     set_frequency,
#      79     set_phase,
#      80     shift_frequency,
#      81     shift_phase,
#      82     snapshot,
#      83     # Channels.
#      84     acquire_channel,
#      85     control_channels,
#      86     drive_channel,
#      87     measure_channel,
#      88     # Contexts.
#      89     align_equispaced,
#      90     align_func,
#      91     align_left,
#      92     align_right,
#      93     align_sequential,
#      94     circuit_scheduler_settings,
#      95     frequency_offset,
#      96     phase_offset,
#      97     transpiler_settings,
#      98     # Macros.
#      99     macro,
#     100     measure,
#     101     measure_all,
#     102     delay_qubits,
#     103     # Circuit instructions.
#     104     cx,
#     105     u1,
#     106     u2,
#     107     u3,
#     108     x,
#     109 )
#     110 from qiskit.pulse.channels import (
#     111     AcquireChannel,
#     112     ControlChannel,
#    (...)
#     117     SnapshotChannel,
#     118 )
#     119 from qiskit.pulse.configuration import (
#     120     Discriminator,
#     121     Kernel,
#     122     LoConfig,
#     123     LoRange,
#     124 )
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\pulse\builder.py:489, in <module>
#     487 from qiskit.circuit.library import standard_gates as gates
#     488 from qiskit.circuit.parameterexpression import ParameterExpression, ParameterValueType
# --> 489 from qiskit.pulse import (
#     490     channels as chans,
#     491     configuration,
#     492     exceptions,
#     493     instructions,
#     494     macros,
#     495     library,
#     496     transforms,
#     497 )
#     498 from qiskit.pulse.instructions import directives
#     499 from qiskit.pulse.schedule import Schedule, ScheduleBlock
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\pulse\instructions\__init__.py:67, in <module>
#      65 from .frequency import SetFrequency, ShiftFrequency
#      66 from .phase import ShiftPhase, SetPhase
# ---> 67 from .play import Play
#      68 from .snapshot import Snapshot
#      69 from .reference import Reference
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\pulse\instructions\play.py:22, in <module>
#      20 from qiskit.pulse.exceptions import PulseError
#      21 from qiskit.pulse.instructions.instruction import Instruction
# ---> 22 from qiskit.pulse.library.pulse import Pulse
#      25 class Play(Instruction):
#      26     """This instruction is responsible for applying a pulse on a channel.
#      27
#      28     The pulse specifies the exact time dynamics of the output signal envelope for a limited
#    (...)
#      31     cycle time, dt, of the backend.
#      32     """
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\pulse\library\__init__.py:116, in <module>
#     100 from .discrete import (
#     101     constant,
#     102     zero,
#    (...)
#     113     drag,
#     114 )
#     115 from .parametric_pulses import ParametricPulse
# --> 116 from .symbolic_pulses import (
#     117     SymbolicPulse,
#     118     ScalableSymbolicPulse,
#     119     Gaussian,
#     120     GaussianSquare,
#     121     GaussianSquareDrag,
#     122     Drag,
#     123     Constant,
#     124 )
#     125 from .pulse import Pulse
#     126 from .waveform import Waveform
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\qiskit\pulse\library\symbolic_pulses.py:36, in <module>
#      34     import symengine as sym
#      35 else:
# ---> 36     import sympy as sym
#      39 def _lifted_gaussian(
#      40     t: sym.Symbol,
#      41     center: Union[sym.Symbol, sym.Expr, complex],
#      42     t_zero: Union[sym.Symbol, sym.Expr, complex],
#      43     sigma: Union[sym.Symbol, sym.Expr, complex],
#      44 ) -> sym.Expr:
#      45     r"""Helper function that returns a lifted Gaussian symbolic equation.
#      46
#      47     For :math:`\sigma=` ``sigma`` the symbolic equation will be
#    (...)
#      71         Symbolic equation.
#      72     """
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\__init__.py:170, in <module>
#     157 from .simplify import (simplify, hypersimp, hypersimilar, logcombine,
#     158         separatevars, posify, besselsimp, kroneckersimp, signsimp,
#     159         nsimplify, FU, fu, sqrtdenest, cse, epath, EPath, hyperexpand,
#     160         collect, rcollect, radsimp, collect_const, fraction, numer, denom,
#     161         trigsimp, exptrigsimp, powsimp, powdenest, combsimp, gammasimp,
#     162         ratsimp, ratsimpmodprime)
#     164 from .sets import (Set, Interval, Union, EmptySet, FiniteSet, ProductSet,
#     165         Intersection, DisjointUnion, imageset, Complement, SymmetricDifference, ImageSet,
#     166         Range, ComplexRegion, Complexes, Reals, Contains, ConditionSet, Ordinal,
#     167         OmegaPower, ord0, PowerSet, Naturals, Naturals0, UniversalSet,
#     168         Integers, Rationals)
# --> 170 from .solvers import (solve, solve_linear_system, solve_linear_system_LU,
#     171         solve_undetermined_coeffs, nsolve, solve_linear, checksol, det_quick,
#     172         inv_quick, check_assumptions, failing_assumptions, diophantine,
#     173         rsolve, rsolve_poly, rsolve_ratio, rsolve_hyper, checkodesol,
#     174         classify_ode, dsolve, homogeneous_order, solve_poly_system,
#     175         solve_triangulated, pde_separate, pde_separate_add, pde_separate_mul,
#     176         pdsolve, classify_pde, checkpdesol, ode_order, reduce_inequalities,
#     177         reduce_abs_inequality, reduce_abs_inequalities, solve_poly_inequality,
#     178         solve_rational_inequalities, solve_univariate_inequality, decompogen,
#     179         solveset, linsolve, linear_eq_to_matrix, nonlinsolve, substitution)
#     181 from .matrices import (ShapeError, NonSquareMatrixError, GramSchmidt,
#     182         casoratian, diag, eye, hessian, jordan_cell, list2numpy, matrix2numpy,
#     183         matrix_multiply_elementwise, ones, randMatrix, rot_axis1, rot_axis2,
#    (...)
#     193         DiagonalOf, trace, DotProduct, kronecker_product, KroneckerProduct,
#     194         PermutationMatrix, MatrixPermute, Permanent, per)
#     196 from .geometry import (Point, Point2D, Point3D, Line, Ray, Segment, Line2D,
#     197         Segment2D, Ray2D, Line3D, Segment3D, Ray3D, Plane, Ellipse, Circle,
#     198         Polygon, RegularPolygon, Triangle, rad, deg, are_similar, centroid,
#     199         convex_hull, idiff, intersection, closest_points, farthest_points,
#     200         GeometryError, Curve, Parabola)
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\solvers\__init__.py:21, in <module>
#      17 from .diophantine import diophantine
#      19 from .recurr import rsolve, rsolve_poly, rsolve_ratio, rsolve_hyper
# ---> 21 from .ode import checkodesol, classify_ode, dsolve, \
#      22     homogeneous_order
#      24 from .polysys import solve_poly_system, solve_triangulated
#      26 from .pde import pde_separate, pde_separate_add, pde_separate_mul, \
#      27     pdsolve, classify_pde, checkpdesol
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\solvers\ode\__init__.py:1, in <module>
# ----> 1 from .ode import (allhints, checkinfsol, classify_ode,
#       2         constantsimp, dsolve, homogeneous_order)
#       4 from .lie_group import infinitesimals
#       6 from .subscheck import checkodesol
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\solvers\ode\ode.py:3563, in <module>
#    3559     return [sol1, sol2, sol3]
#    3562 #This import is written at the bottom to avoid circular imports.
# -> 3563 from .single import SingleODEProblem, SingleODESolver, solver_map
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\solvers\ode\single.py:36, in <module>
#      31 from .hypergeometric import equivalence_hypergeometric, match_2nd_2F1_hypergeometric, \
#      32     get_sol_2F1_hypergeometric, match_2nd_hypergeometric
#      33 from .nonhomogeneous import _get_euler_characteristic_eq_sols, _get_const_characteristic_eq_sols, \
#      34     _solve_undetermined_coefficients, _solve_variation_of_parameters, _test_term, _undetermined_coefficients_match, \
#      35         _get_simplified_sol
# ---> 36 from .lie_group import _ode_lie_group
#      39 class ODEMatchError(NotImplementedError):
#      40     """Raised if a SingleODESolver is asked to solve an ODE it does not match"""
#
# File c:\Users\dormi\AppData\Local\Programs\Python\Python39\lib\site-packages\sympy\solvers\ode\lie_group.py:34, in <module>
#      31 from sympy.simplify import (collect, powsimp,  # type: ignore
#      32     separatevars, simplify)
#      33 from sympy.solvers import solve
# ---> 34 from sympy.solvers.pde import pdsolve
#      36 from sympy.utilities import numbered_symbols
#      37 from sympy.solvers.deutils import _preprocess, ode_order
#
# File <frozen importlib._bootstrap>:1007, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:982, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:925, in _find_spec(name, path, target)
#
# File <frozen importlib._bootstrap_external>:1423, in find_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1395, in _get_spec(cls, fullname, path, target)
#
# File <frozen importlib._bootstrap_external>:1522, in find_spec(self, fullname, target)
#
# File <frozen importlib._bootstrap_external>:142, in _path_stat(path)
#
# KeyboardInterrupt:

# %% [markdown]
# 1. Code to create the quantum circuits for each step, to change circuits & to change measurements.

# %%
kR = np.pi/4.0 #rotation angle for the rotation gates

#gate labels: 0 = I, 1 = H, 2 = X, 3 = Rup, 4 = Rdown, 5 = CX1, 6 = CX2

def createCircuit(data): #function that creates a circuit using the gates selected in the Launchpad. 
    circ = qk.QuantumCircuit(3)
    for i in range(3):
        #add X gates
        if data[i] == 2: #the data is a list of 3 integers, each one representing a qubit. The integers are the gate labels. 
            circ.x(i)
        #add H gates
        if data[i] == 1:
            circ.h(i)
        #add CX gates. The CX gate is a two-qubit gate, so we need to search for the other qubit.
        if data[i] == 5:
            #search for the other qubit
            for j in range(3):
                if data[j] == 6:
                    circ.cx(i, j)
                    break
        
        #add rotation gates. Gate Rz is a rotation around the z axis (vertical axis). That's phi in the Bloch sphere.
        if data[i] == 3: #rotation gate for the up state
            circ.rz(kR, i) 
        if data[i] == 4: #rotation gate for the down state
            circ.rz(-kR, i)
    return circ

def changeCircuit(data, i): #function that changes/updates a circuit in the circuits list
    global circuits
    circuits[i] = createCircuit(data)

def changeMeasure(nqubit, step): #function that changes/updates the measure matrix
    global MM
    #print(nqubit, step)
    MM[step][nqubit] = not MM[step][nqubit] #this acts like a toggle switch within the annotation/measure mode in the Launchpad.

# %% [markdown]
# 2. Code to define measurements and annotations.

# %%
#This is an example of a state:
#            0        1        2        3         4         5         6         7
# state = 0 |000>+ 2 |001>+ 5 |010>+ 2 |011> + 4 |100> + 6 |101> + 2 |110> + 0 |111>  (notation: |q0q1q2>)
#The labels above are the decimal numbers correspponding to the binary numbers of the basis vectors. (Ex: 011 binary -> 3 decimal)
#These are the coefficients: [0, 2, 5, 2, 4, 6, 2, 0]
#We want this function: getCoeff(state, 011) -> 2     (state[3] = 2)

def getCoeff(_state, b3, b2, b1): #function that returns the coefficient of a state
    index = int(b3 + 2*b2 + 4*b1) #convert binary to decimal
    return _state.data[index]

def extract(A, M1, M2): #A, M1 and M2 are the boolean values of a step in the MM measure matrix. This function annotates/measures if told to do show so through boolen values in each step. 
    global quantumState #current complex vector of coefficients

    #q1 wave function has to be collapsed (measured) if we want to either annonate q0 or measure q1.
    #The entanglement induces hyperspheres and we can no longer anonnate the angle of Bloch unless we collapse q1.
    #When q1 collapses, q0 looses some information and goes back to a 2D space, so that we can annotate the Bloch's angle.
    #The same exact process applies to q2.

    bM1 = A or M1 #boolean value. If A or M1 are true, then bM1 is true and has to be collapsed.
    bM2 = A or M2 #boolean value. If A or M2 are true, then bM2 is true and has to be collapsed.

    rA = -1 #variable that stores the result of the annotation value
    rM1 = -1 #variable that stores the result of the measurement of q1
    rM2 = -1 #same as RM1 but for q2
    rCM1 = -1 #variable that stores the result of the collapsed q1 when we annotate q0
    rCM2 = -1 #same as rCM1 but for q2

    #first, collapse q1 if needed, and store the value if needed
    if bM1:
        (rCM1, stateM1) = quantumState.measure([1]) #collapse second qubit
        if M1:
            rM1 = int(rCM1)
        quantumState = stateM1

    #then, collapse q2 if needed, and store the value if needed
    if bM2:
        (rCM2, stateM2) = (rCM1, stateM1) = quantumState.measure([2])
        if M2:
            rM2 = int(rCM2)
        quantumState = stateM2

    #finally, if we want to anotate, get resulting coeffs and calculate bloch angles
    if A:

        #when q1 and q2 are collapsed, the Bloch sphere remaining is in the space c0|0 rCM1 rCM2> + c1|1 rCM1 rCM2>
        c0 = getCoeff(quantumState, 0, int(rCM1), int(rCM2))
        c1 = getCoeff(quantumState, 1, int(rCM1), int(rCM2))

        #get bloch angles from coefficients c0 and c1, where
        # |q0> = c0|0> + c1|1>
        phi = np.angle(c1)-np.angle(c0) #angle() returns the phase of a complex number
        if c1==0.0 or c0==0.0: #if c1 or c0 are zero, then the angle needs a scale factor of 2
            phi *= 2.0

        #quantize phi (it is a multiple of pi/8 = kR) to avoid precision errors
        rA = int(np.round(phi/(kR)))
        #make it positive
        if rA < 0:
            rA += 8
    
    return (rA, rM1, rM2)

# %% [markdown]
# 3. Code to fill the circuits and the MM variables.

# %%
circuits = [createCircuit([0,0,0]) for i in range(16)] #list of circuits full with empty values or 0s, which are identity gates, that is updated in each step

MM = [[False for i in range(3)] for j in range(16)] #matrix of False boolean values that is updated in each step

MG =  [[0 for i in range(3)] for j in range(16)] #matrix of gate labels that is updated in each step

quantumState = Statevector.from_label('000') #initial state
